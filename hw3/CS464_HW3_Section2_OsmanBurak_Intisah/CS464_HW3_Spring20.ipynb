# %% [markdown]
# <h1><center>CS 464</center></h1>
# <h1><center>Introduction to Machine Learning</center></h1>
# <h1><center>Spring 2020</center></h1>
# <h1><center>Homework 3</center></h1>

# %% [markdown]
# # HERE I AM PROVIDING MY GOOGLE DRIVE FOLDER WHICH INCLUDES THE MODEL
# ### My google drive folder
# https://drive.google.com/drive/folders/1KLStmaVlY8l7gpe6RInd_wn_ltrlcyTT?usp=sharing
# ### My google colab page which I have used
# https://colab.research.google.com/drive/1nbm3lUykmbpgtajFrGwfv-g-e_97ZrBw?usp=sharing

# %% [markdown]
# <h3><center>Due: May 19, 2020 23:55 (GMT+3)</center></h3>

# %% [markdown]
# ### Instructions
#
# <ul>
#     <li>
#     This homework contains both written and programming questions about neural networks. You should implement programming questions on this notebook. Each programming question has its own cell for your answer. You can implement your code directly in these cells, or you can call required functions which are defined in a different location for the given question. <b>Any other programming enviroment will NOT be accepted.</b>
#     </li>
#     <li>
#     For questions that you need to plot, your plot results have to be included in both cell output. For written questions, you may provide them either as comments in code cells or as seperate text cells.
#     </li>
#     <li>
#     You are <b>ONLY ALLOWED</b> to use libraries given below:
#         <ul>
#         <i>>google.colab.drive</i><br>
#          <i>>pandas</i><br>
#          <i>>numpy</i><br>
#          <i>>libraries included in Python standard library (time, os, sys etc.)</i><br>
#          <i>>libraries included in PyTorch framework (torch, torchvision etc.)</i><br>
#          <i>>PIL.Image</i><br>
#          <i>>matplotlib</i>
#         </ul>
#     </li>
#     <li>
#     It is <b>NOT ALLOWED</b> to use a different deep learning framework than PyTorch.
#     </li>
#     <li>
#     You will submit only a single compressed file for this homework. Compress your notebook(".ipynb") and model (".pth") files as a gzipped TAR file or a ZIP file with the name CS464_HW3_Section#_Firstname_Lastname. Do not use any Turkish letters for any of your files including code files and model files. Upload your homework to the related section on Moodle.
#     </li>
#     <li>
#     This is an individual assignment for each student. That is, you are NOT allowed to share your workwith your classmates.</li>
#     <li>
#     If you do not follow the submission routes, deadlines and specifications, it will lead to a significant grade deduction.
#     </li>
#     <li>
#     For any question regarding this assignment, contact <b>ilayda.beyreli@bilkent.edu.tr</b>.
#     </li>
# </ul>

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# You may use both anaconda or pip to install PyTorch to your own computer.

# %% [markdown]
# ### Anaconda Installation
#
# <ul>
#     <li>Download anaconda from https://www.anaconda.com/download</li>
#     <li>Follow the instructions provided in https://conda.io/docs/user-guide/install/index.html#regular-installation</li>
# </ul>
#
# #### Creation of Virtual Environment
#
# <ul>
#     <li>Create python3.7 virtual environment for your hw3 using follow command from the command line<br>
#         <i>> conda create -n HW3 python=3.7 anaconda</i></li>
#     <li>Activate your virtual environment<br>
#         <i>> source activate HW3</i></li>
#     <li>When you create your virtual environment with "anaconda" metapackage, jupyter notebook should be installed. Try:<br>
#          <i>> jupyter notebook</i>
# </ul>
#
#
# #### Pytorch Installation with Anaconda
#
# You should install PyTorch to your virtual environment which is created for the hw3. Therefore, you should activate your homework virtual environment before to start PyTorch installation.
# <li>> source activate HW3</li>
#
# After you have activated the virtual environment, then use one of the following commands to install pytorch for CPU for your system. See https://pytorch.org/ for help.
# <ul>
# <li>For MacOS:<br>
#     <i>> conda install pytorch torchvision -c pytorch</i>
# </li>
# <li>For Linux:<br>
#     <i>> conda install pytorch-cpu torchvision-cpu -c pytorch</i>
# </li>
# <li>For Windows:<br>
#     <i>> conda install pytorch-cpu torchvision-cpu -c pytorch</i><br>
# </li></ul>

# %% [markdown]
# ###Pip3 Installation
# <ul>
#     <li>Download pip3 from https://pip.pypa.io/en/stable/installing/</li>
#     <li>If you are using Windows, you may need to add Python to your enviroment variables. You may use the following tutorial to install Python and pip.
#     https://phoenixnap.com/kb/how-to-install-python-3-windows</li>
# </ul>
#
# #### PyTorch Installation with Pip
# <ul>
# <li>For MacOS:<br>
#     <i>> pip3 install torch torchvision</i>
# </li>
# <li>For Linux:<br>
#     <i>> pip3 install torch==1.3.1+cpu torchvision==0.4.2+cpu -f https://download.pytorch.org/whl/torch_stable.html</i>
# </li>
# <li>For Windows:<br>
#     <i>> pip3 install torch==1.3.1+cpu torchvision==0.4.2+cpu -f https://download.pytorch.org/whl/torch_stable.html</i><br>
# </li>

# %% [markdown]
# ## Question 1 Decison Trees [30 pts]

# %% [markdown]
# ![Dataset](https://drive.google.com/uc?export=view&id=1k6-cF0zIJ2TFtey1WZ8Y5wevWcDtKckd)
#
#   Consider the dataset shown above. You will train a binary decision tree using information gain as the splitting criteria. Consider the following stopping criteria (ie. early pruning criteria): If the entropy of a node is below a predefined threshold, $T$, stop splitting that node, and set it as a leaf.<br>
#
#  Reminder: You are not allowed to put scanned images. Hence, you need to use drawing tools such as draw.io, Paint, Microsoft Powerpoint etc.<br>
#
# **a) [10 pts]** Draw the decision tree that is trained on this dataset without any pruning (i.e. $T=0$). Use <b>ID3 algorithm</b> and <b>entropy</b> as your impurity measure to construct your tree. Show your calculation for each split decision and justify your answer clearly.<br>
#
# **b) [5 pts]** Draw the decision boundaries resulting from the decision tree you have drawn for part a.<br>
#
# **c) [5 pts]** Assume we have a very large balanced dataset with 2 classes. Draw a hypothetical plot, which shows training and test errors (Y-axis) as $T$ changes from 1 to 0 (X-axis). Explain your rationale explicitly.<br>
#
# **d) [5 pts]** Is ID3 algorithm optimal? If yes, provide an intuition of optimality. If not, explain the reason explicitly.<br>
#
# **e) [5 pts]** If you used Gini Index as your impurity measure instead of entropy, would you obtain the same tree as in part a? Explain your reasoning clearly.<br>

# %% [markdown]
# ## Question 2 [70 pts]

# %% [markdown]
# In this question you are asked to perform binary classification on Ocular Disease Recognition, ODIR5k, dataset. First, you will implement a three-layer neural network, and then a 3 layer convolutional neural network (CNN) to classify retinal images of 3500 patiens as either "normal" or "abnormal/disease".<br><br>
# The dataset has been preprocessed in such a way that the right and the left retinal images from the same patient are combined, downsized and stored as H:128 X W:256 RGB images. The label for each patient is also given to you in another .xlsx file.

# %% [markdown]
# ### 2.1. Multi Layer Perceptron (MLP) [30 pts]

# %% [markdown]
# #### Data Loader [7pts]
#
# An important part of such a task is to implement your own data loader. In this homework, a partial loader is provided to you. This loader is going to be based on a base class named "Dataset", provided in PyTorch library. You need to complete the code below to create your custom "OcularDataset" class which will be able to load your dataset. <br><br>
# Implement the functions whose proptotypes are given. Follow the TODO notes below. You have to divide the files into three sets as <b>train (5/7)</b>, <b>validation (1/7)</b> and **test (1/7)** sets.  These non-overlapping splits, which are subsets of OcularDataset, should be retrieved using the "get_dataset" function. Here, you are also supposed to flatten the image into a vector (also to grayscale) to be compatible with MLP. Note that the pixel values also needs to be normalized to [0,1] range.
# <br><br>
#
# Hint: The dataset is not normalized and your results will heavily depend on your input.

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
root = '/content/gdrive/My Drive/Colab Notebooks/Homework3'
# Out:
# Mounted at /content/gdrive

# %%
import os
import cv2
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from torch.utils.data import Dataset
import torch
from PIL import Image

# %%
class OcularDataset(Dataset):
    
    # TODO:
    # Define constructor for AnimalDataset class
    # HINT: You can pass processed data samples and their ground truth values as parameters 
    def __init__(self, data, label, **kwargs):
        self.data = data
        self.label = label
        
    # '''This function should return sample count in the dataset'''
    def __len__(self):
        return self.data.shape[0]

    # '''This function should return a single sample and its ground truth value from the dataset corresponding to index parameter '''
    def __getitem__(self, index):
        _x = self.data[index]
        _y = self.label[index]
        return _x, _y

def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

def get_dataset(root):
    # TODO: 
    # Read dataset files
    # Construct training, validation and test sets
    # Normalize & flatten datasets
    
    # I assumed that my root file contains a file with images folder and label.xlsx excel file.
    # According to this assumption I have done the followings
    file = os.path.join(root, 'labels.xlsx')
    xl = pd.ExcelFile(file)
    labels = xl.parse('Sheet1')
    img_dir =  os.path.join(root, 'images')
    # print("Image Directory: {}".format (.img_dir))

    # I find the length of image data
    all_images = os.listdir(img_dir)
    print(all_images)
    np.random.shuffle(all_images)
    print(all_images)
    total = len (all_images)
    
    # find the length of train, val, test data sets
    train_len = int(total * 5 / 7)
    val_len = int(total * 1 / 7)
    test_len = int(total * 1 / 7)
    
    
    # according to these numbers I have divided the datas into train, val and test data sets.
    # taking train data
    print("Loading Training Data")
    train_data = []
    train_gt = []
    for i in range (0,train_len):

        img_name = all_images[i]
        img_address = os.path.join(img_dir,img_name)
        # print(img_address)
        # opening image in greyscale
        vec = Image.open(img_address).convert("L")
        img = np.array(vec).flatten()
        # in order to normalize
        img = NormalizeData(img)
        train_data.append(img)
        
        img_id = os.path.splitext(img_name)[0]
        for j in range (0,3500):
          if  labels[0][j] == int(img_id):
            train_gt.append( np.array(labels[1][j]))
            break
        if (i%500 == 0):
          print("Loaded: {}".format(i))
    
    # taking val data
    print("Loading Validation Data")
    val_data = []
    val_gt = []
    start = train_len
    end = train_len + val_len
    for i in range (train_len,train_len+val_len):
        img_name = all_images[i]
        img_address = os.path.join(img_dir,img_name)
        # opening image in greyscale
        vec = Image.open(img_address).convert("L")
        img = np.array(vec).flatten()
        # in order to normalize
        img = NormalizeData(img)
        val_data.append(img)

        img_id = os.path.splitext(img_name)[0]
        for j in range (0,3500):
          if  labels[0][j] == int(img_id):
            val_gt.append( np.array(labels[1][j]))
            break
        if (i%100 == 0):
          print("Loaded: {}".format(i))
    


    # taking test data
    print("Loading Test Data")
    test_data = []
    test_gt = []
    start = train_len + val_len
    for i in range (start,total):
        img_name = all_images[i]
        img_address = os.path.join(img_dir,img_name)
        # opening image in greyscale
        vec = Image.open(img_address).convert("L")
        img = np.array(vec).flatten()
        # in order to normalize
        img = NormalizeData(img)
        test_data.append(img)

        img_id = os.path.splitext(img_name)[0]
        for j in range (0,3500):
          if  labels[0][j] == int(img_id):
            test_gt.append( np.array(labels[1][j]))
            break
        if (i%100 == 0):
          print("Loaded: {}".format(i))
    
    # Training data should be in type float
    train_data = np.asarray(train_data,dtype="float")
    val_data = np.asarray(val_data,dtype="float")
    test_data = np.asarray(test_data,dtype="float")

    # Converting to np array
    train_gt = np.asarray(train_gt).reshape(-1,1)
    val_gt = np.asarray(val_gt).reshape(-1,1)
    test_gt = np.asarray(test_gt).reshape(-1,1)

    # creating Dataset objects
    train_dataset = OcularDataset (data = train_data, label= train_gt )
    val_dataset = OcularDataset (data = val_data, label = val_gt )
    test_dataset = OcularDataset (data = test_data, label=test_gt )
    
    return train_dataset, val_dataset, test_dataset

# %% [markdown]
# #### Neural Network [4 pts]
#
# Now, implement your three hidden layer neural network. FNet class will represent your neural network. The layer descriptions are as follows:<ul>
#     <i>> Input layer will have ReLU activation. You should decide the number of input neurons.</i><br>
#     <i>> First hidden layer will have 1024 neuros with ReLU activation </i><br>
#     <i>> Second hidden layer will have 256 neuros with ReLU activation </i><br>
#     <i> You should decide the number of output neurons and pick a proper activation function for the output layer. </i><br>
# </ul>

# %%
# needed imports for following sections
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.autograd import Variable

# %%
# why this returns false
print(torch.cuda.device_count())
print (torch.cuda.is_available())
# Out:
# 1
# True

# %%
class FNet(nn.Module):
    '''Define your neural network'''
    def __init__(self, layer1, layer2, **kwargs): 
    # you can add any additional parameters you want 
    # TODO:
    # You should create your neural network here
        super().__init__()
        first_layer = layer1
        second_layer = layer2
        # hidden layer 1
        self.hidden_layer1 = nn.Linear(32768, first_layer)
        # hidden layer 2
        self.hidden_layer2 = nn.Linear(first_layer, second_layer)
        # in the homework description you have provided there should be 3 hiden layers but 
        # I though that output layer is not a hidden layer 
        # so I named it as output layer
        self.output_layer = nn.Linear(second_layer, 1)
     
    def forward(self, X): 
    # you can add any additional parameters you want
    # TODO:
    # Forward propagation implementation should be here
        sze = X.size(0)
        X = F.relu(self.hidden_layer1(X))
        X = F.relu(self.hidden_layer2(X))
        # Flatten the tensor 
        X = X.view(sze, -1) 
        X = self.output_layer(X)
        # for numerical stability as our TA said
        return X

# %% [markdown]
# #### Training [10 pts]
#
# Complete the code snippet below to train your network. You need to carefully select the appropriate loss function and tune hyper-parameters. Use SGD optimizer for this question.<br>
# So far, you should have created three dataset splits for train, validation and test. You will need to load these splits at this phase. Make sure that you shuffle the samples in the training split. Save training loss and training accuracy of each iteration (each batch) and also save validation loss and accuracy at each epoch to use them in the next part for plotting.<br>
# Your model is going to run upto at most 100 epochs. Pick the best model so far as your final model and save this model as a ".pth" file. <br>
# Note that the best accuracy does not always imply the best model. Try to track losses instead of accuracies.

# %%
def binary_acc(y_pred, y_test):
    y_pred_tag = torch.round(torch.sigmoid(y_pred))

    correct_results_sum = (y_pred_tag == y_test).sum().float()
    acc = correct_results_sum/y_test.shape[0]
    acc = torch.round(acc * 100)
    
    return acc

''' Train your network for a one epoch '''
#  CAREFUL I have swaped with main and train/test 

def train(epoch, model, criterion, optimizer, loader): # you are free to change parameters
    model.train()

    correct = 0
    train_acc= 0
    train_loss = 0
    tot_loss = 0
    count = 0
    all_train_acc = []
    for batch_idx, (data, labels) in enumerate(loader):
        # TODO:
        # Implement training code for a one iteration
        
        # Using autograd Variable
        data, labels = Variable(data), Variable(labels)
        
        # zero out the gradient in order to do the parameter update correctly.
        optimizer.zero_grad()
        
        # giving data to model
        output = model(data.float())

        # calculating the loss and adding it to an array
        loss = criterion (output, labels.float())
        tot_loss += loss.item()

        loss.backward()
        optimizer.step()

        # calculating accuracy for each step and adding to an array
        # get the index of the max log-probability
        train_acc = binary_acc(output, labels)
        all_train_acc.append(train_acc)

        if batch_idx % 50 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} , Accuracy:({})\n'.format(
                epoch, batch_idx * len(data), len(loader.dataset), 100. * batch_idx / len(loader), loss.item(), train_acc))
    
    
    avg_loss = (tot_loss / len(loader.dataset)) 
    avg_acc = sum(all_train_acc) / len(all_train_acc) 
    print('Train set: Average loss: {:.4f}, Accuracy:({})\n'.format(avg_loss, avg_acc))
    
    print("-------------------------------------------------------")


    return avg_acc, avg_loss


''' Test&Validate your network '''
def test(model, loader, criterion): # you are free to change parameters

    model.eval()
    test_loss = 0
    correct = 0
    all_test_acc = []
    with torch.no_grad():
        for batch_idx, (data, labels) in enumerate(loader):
            # TODO:
            # Implement test code
            
            # Using autograd Variable
            data, labels = Variable(data), Variable(labels)

            # giving data to model
            output = model(data.float())
            
            # sum up batch loss
            loss = criterion(output, labels.float())
            test_loss +=  loss.item()

            # get the index of the max log-probability
            test_acc = binary_acc(output, labels)
            all_test_acc.append(test_acc)

            if batch_idx % 50 == 0:
              print('Test Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} , Accuracy:({})\n'.format(
                  epoch, batch_idx * len(data), len(loader.dataset), 100. * batch_idx / len(loader), loss.item(), test_acc))

    avg_loss = test_loss / len(loader.dataset)
    avg_acc = sum(all_test_acc) / len(all_test_acc) 

    print('Test set: Average loss: {:.4f}, Accuracy:({})\n'.format(avg_loss, avg_acc))
    
    print("*************************************************************************************************************************************")
        
    return avg_acc, avg_loss
        
# -----------------------------------------------------------------------------------------------------------------------

#HINT: note that your training time should not take many days.

#TODO:
#Pick your hyper parameters
max_epoch = 100
train_batch = 32
test_batch = 16

learning_rate = 0.0005

use_gpu = torch.cuda.is_available()


# Main START HERE
def main(): # you are free to change parameters

    # Create train dataset loader
    # Create validation dataset loader
    # Create test dataset loader
    # initialize your GENet neural network
    # define your loss function
    print("MY MAIN FUNTION STARTS BELOW")

# %% [markdown]
# ## My Main Function STARTS HERE
# ###### For not calculating the same thing again and again I have taken out the main from the function

# %%
print("Current Directory")
print(root)
# os.listdir(root)

print("Data is loading..")
training, val, testing = get_dataset(root)

trainloader = DataLoader(dataset=training, batch_size=train_batch, shuffle=True)
g', '229.jpg', '2030.jpg', '292.jpg', '2513.jpg', '3176.jpg', '3086.jpg', '1549.jpg', '2887.jpg', '2877.jpg', '3997.jpg', '518.jpg', '3131.jpg', '4155.jpg', '3364.jpg', '1644.jpg', '4573.jpg', '812.jpg', '4326.jpg', '4334.jpg', '2383.jpg', '233.jpg', '4659.jpg', '1213.jpg', '212.jpg', '2612.jpg', '3161.jpg', '1028.jpg', '3031.jpg', '1600.jpg', '619.jpg', '746.jpg', '468.jpg', '2435.jpg', '4495.jpg', '2771.jpg', '4385.jpg', '4511.jpg', '2409.jpg', '177.jpg', '3064.jpg', '2460.jpg', '60.jpg', '1444.jpg', '736.jpg', '3367.jpg', '908.jpg', '2407.jpg', '2236.jpg', '3978.jpg', '1163.jpg', '48.jpg', '4126.jpg', '2242.jpg', '1968.jpg', '3095.jpg', '2802.jpg', '1402.jpg', '2623.jpg', '970.jpg', '1270.jpg', '1389.jpg', '63.jpg', '3004.jpg', '765.jpg', '787.jpg', '737.jpg', '2239.jpg', '797.jpg', '1865.jpg', '2594.jpg', '268.jpg', '1248.jpg', '4311.jpg', '2927.jpg', '3434.jpg', '1217.jpg', '2920.jpg', '4060.jpg', '3249.jpg', '4533.jpg', '548.jpg', '2694.jpg', '2732.jpg', '2500.jpg', '892.jpg', '4404.jpg', '4007.jpg', '1301.jpg', '2560.jpg', '1131.jpg', '3292.jpg', '1571.jpg', '4105.jpg', '3145.jpg', '102.jpg', '1473.jpg', '2940.jpg', '1623.jpg', '4058.jpg', '2848.jpg', '729.jpg', '1562.jpg', '852.jpg', '2664.jpg', '490.jpg', '972.jpg', '3388.jpg', '2333.jpg', '2551.jpg', '2523.jpg', '2804.jpg', '3347.jpg', '4365.jpg', '896.jpg',  ...
# Loading Training Data
# Loaded: 0
# Loaded: 500
# Loaded: 1000
# Loaded: 1500
# Loaded: 2000
# Loading Validation Data
# Loaded: 2500
# Loaded: 2600
# Loaded: 2700
# Loaded: 2800
# Loaded: 2900
# Loading Test Data
# Loaded: 3000
# Loaded: 3100
# Loaded: 3200
# Loaded: 3300
# Loaded: 3400

# %%
# initializing my neural network
print("Neural Network Initiliazing..")
model = FNet(1024, 256)
print(model)
# you can play with momentum and weight_decay parameters as well
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.8, weight_decay=3e-02)
# Out:
# Neural Network Initiliazing..
# FNet(
#   (hidden_layer1): Linear(in_features=32768, out_features=1024, bias=True)
#   (hidden_layer2): Linear(in_features=1024, out_features=256, bias=True)
#   (output_layer): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
# start training
# for each epoch calculate validation performance
# save best model according to validation performance
criterion = nn.BCEWithLogitsLoss()
print("Training Start..")
# just to be sure best acc = 0 every time
best_acc = 0

validation_losses = []
validation_accs = []
train_losses = []
train_accs = []

for epoch in range(max_epoch):
    
    train_acc_epoch, train_loss_epoch = train(epoch, model, criterion,  optimizer, trainloader)
    # getting arrays of training data
    train_losses.append(train_loss_epoch)
    train_accs.append(train_acc_epoch)
    
    # these acc and loss are calculated from our validation dataset
    val_acc_epoch, val_loss_epoch = test(model, val_loader, criterion)
    # getting the array of val data
    validation_losses.append(val_loss_epoch)
    validation_accs.append(val_acc_epoch)
    
    if val_acc_epoch > best_acc:
        # need to change best acc every time new accuracy is better than before 
        best_acc = val_acc_epoch
        torch.save(model, root + "/model.pth")
# Out:
# Training Start..
# Train Epoch: 0 [0/2500 (0%)]	Loss: 0.697453 , Accuracy:(41.0)
#
# Train Epoch: 0 [1600/2500 (63%)]	Loss: 0.614439 , Accuracy:(66.0)
#
# Train set: Average loss: 0.0201, Accuracy:(65.7848129272461)
#
# -------------------------------------------------------
# Test Epoch: 0 [0/500 (0%)]	Loss: 0.697816 , Accuracy:(59.0)
#
# Test set: Average loss: 0.0200, Accuracy:(68.375)
#
# *************************************************************************************************************************************
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type FNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Train Epoch: 1 [0/2500 (0%)]	Loss: 0.673994 , Accuracy:(62.0)
#
# Train Epoch: 1 [1600/2500 (63%)]	Loss: 0.609313 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0199, Accuracy:(66.84809875488281)
#
# -------------------------------------------------------
# Test Epoch: 1 [0/500 (0%)]	Loss: 0.543190 , Accuracy:(78.0)
#
# Test set: Average loss: 0.0199, Accuracy:(68.4375)
#
# *************************************************************************************************************************************
# Train Epoch: 2 [0/2500 (0%)]	Loss: 0.761401 , Accuracy:(50.0)
#
# Train Epoch: 2 [1600/2500 (63%)]	Loss: 0.592643 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0199, Accuracy:(66.98734283447266)
#
# -------------------------------------------------------
# Test Epoch: 2 [0/500 (0%)]	Loss: 0.648696 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0199, Accuracy:(68.375)
#
# *************************************************************************************************************************************
# Train Epoch: 3 [0/2500 (0%)]	Loss: 0.612953 , Accuracy:(69.0)
#
# Train Epoch: 3 [1600/2500 (63%)]	Loss: 0.725250 , Accuracy:(59.0)
#
# Train set: Average loss: 0.0199, Accuracy:(66.67088317871094)
#
# -------------------------------------------------------
# Test Epoch: 3 [0/500 (0%)]	Loss: 0.574491 , Accuracy:(75.0)
#
# Test set: Average loss: 0.0200, Accuracy:(67.9375)
#
# *************************************************************************************************************************************
# Train Epoch: 4 [0/2500 (0%)]	Loss: 0.643533 , Accuracy:(66.0)
#
# Train Epoch: 4 [1600/2500 (63%)]	Loss: 0.674416 , Accuracy:(62.0)
#
# Train set: Average loss: 0.0199, Accuracy:(66.60759735107422)
#
# -------------------------------------------------------
# Test Epoch: 4 [0/500 (0%)]	Loss: 0.552735 , Accuracy:(78.0)
#
# Test set: Average loss: 0.0199, Accuracy:(68.3125)
#
# *************************************************************************************************************************************
# Train Epoch: 5 [0/2500 (0%)]	Loss: 0.587303 , Accuracy:(75.0)
#
# Train Epoch: 5 [1600/2500 (63%)]	Loss: 0.572446 , Accuracy:(75.0)
#
# Train set: Average loss: 0.0199, Accuracy:(66.64556884765625)
#
# -------------------------------------------------------
# Test Epoch: 5 [0/500 (0%)]	Loss: 0.518568 , Accuracy:(81.0)
#
# Test set: Average loss: 0.0198, Accuracy:(68.6875)
#
# *************************************************************************************************************************************
# Train Epoch: 6 [0/2500 (0%)]	Loss: 0.675967 , Accuracy:(59.0)
#
# Train Epoch: 6 [1600/2500 (63%)]	Loss: 0.665509 , Accuracy:(66.0)
#
# Train set: Average loss: 0.0198, Accuracy:(66.89873504638672)
#
# -------------------------------------------------------
# Test Epoch: 6 [0/500 (0%)]	Loss: 0.627420 , Accuracy:(69.0)
#
# Test set: Average loss: 0.0199, Accuracy:(68.3125)
#
# *************************************************************************************************************************************
# Train Epoch: 7 [0/2500 (0%)]	Loss: 0.661250 , Accuracy:(62.0)
#
# Train Epoch: 7 [1600/2500 (63%)]	Loss: 0.675593 , Accuracy:(59.0)
#
# Train set: Average loss: 0.0198, Accuracy:(66.87342071533203)
#
# -------------------------------------------------------
# Test Epoch: 7 [0/500 (0%)]	Loss: 0.622213 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0198, Accuracy:(68.625)
#
# *************************************************************************************************************************************
# Train Epoch: 8 [0/2500 (0%)]	Loss: 0.672668 , Accuracy:(59.0)
#
# Train Epoch: 8 [1600/2500 (63%)]	Loss: 0.499854 , Accuracy:(84.0)
#
# Train set: Average loss: 0.0198, Accuracy:(66.88607788085938)
#
# -------------------------------------------------------
# Test Epoch: 8 [0/500 (0%)]	Loss: 0.721502 , Accuracy:(56.0)
#
# Test set: Average loss: 0.0198, Accuracy:(68.875)
#
# *************************************************************************************************************************************
# Train Epoch: 9 [0/2500 (0%)]	Loss: 0.692393 , Accuracy:(56.0)
#
# Train Epoch: 9 [1600/2500 (63%)]	Loss: 0.630398 , Accuracy:(66.0)
#
# Train set: Average loss: 0.0198, Accuracy:(66.89873504638672)
#
# -------------------------------------------------------
# Test Epoch:
, Accuracy:(62.0)
#
# Train set: Average loss: 0.0197, Accuracy:(66.9493637084961)
#
# -------------------------------------------------------
# Test Epoch: 52 [0/500 (0%)]	Loss: 0.540689 , Accuracy:(78.0)
#
# Test set: Average loss: 0.0198, Accuracy:(68.25)
#
# *************************************************************************************************************************************
# Train Epoch: 53 [0/2500 (0%)]	Loss: 0.693667 , Accuracy:(59.0)
#
# Train Epoch: 53 [1600/2500 (63%)]	Loss: 0.577874 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0197, Accuracy:(66.62025451660156)
#
# -------------------------------------------------------
# Test Epoch: 53 [0/500 (0%)]	Loss: 0.539604 , Accuracy:(78.0)
#
# Test set: Average loss: 0.0197, Accuracy:(68.625)
#
# *************************************************************************************************************************************
# Train Epoch: 54 [0/2500 (0%)]	Loss: 0.623565 , Accuracy:(66.0)
#
# Train Epoch: 54 [1600/2500 (63%)]	Loss: 0.629268 , Accuracy:(66.0)
#
# Train set: Average loss: 0.0197, Accuracy:(66.64556884765625)
#
# -------------------------------------------------------
# Test Epoch: 54 [0/500 (0%)]	Loss: 0.528328 , Accuracy:(78.0)
#
# Test set: Average loss: 0.0196, Accuracy:(68.75)
#
# *************************************************************************************************************************************
# Train Epoch: 55 [0/2500 (0%)]	Loss: 0.578003 , Accuracy:(72.0)
#
# Train Epoch: 55 [1600/2500 (63%)]	Loss: 0.701772 , Accuracy:(56.0)
#
# Train set: Average loss: 0.0196, Accuracy:(66.91139221191406)
#
# -------------------------------------------------------
# Test Epoch: 55 [0/500 (0%)]	Loss: 0.613383 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0198, Accuracy:(68.125)
#
# *************************************************************************************************************************************
# Train Epoch: 56 [0/2500 (0%)]	Loss: 0.702320 , Accuracy:(59.0)
#
# Train Epoch: 56 [1600/2500 (63%)]	Loss: 0.595672 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0197, Accuracy:(66.60759735107422)
#
# -------------------------------------------------------
# Test Epoch: 56 [0/500 (0%)]	Loss: 0.606508 , Accuracy:(72.0)
#
# Test set: Average loss: 0.0196, Accuracy:(69.0)
#
# *************************************************************************************************************************************
# Train Epoch: 57 [0/2500 (0%)]	Loss: 0.550959 , Accuracy:(75.0)
#
# Train Epoch: 57 [1600/2500 (63%)]	Loss: 0.680447 , Accuracy:(62.0)
#
# Train set: Average loss: 0.0198, Accuracy:(66.68354797363281)
#
# -------------------------------------------------------
# Test Epoch: 57 [0/500 (0%)]	Loss: 0.626412 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0197, Accuracy:(68.875)
#
# *************************************************************************************************************************************
# Train Epoch: 58 [0/2500 (0%)]	Loss: 0.589743 , Accuracy:(66.0)
#
# Train Epoch: 58 [1600/2500 (63%)]	Loss: 0.599698 , Accuracy:(69.0)
#
# Train set: Average loss: 0.0198, Accuracy:(66.3417739868164)
#
# -------------------------------------------------------
# Test Epoch: 58 [0/500 (0%)]	Loss: 0.697676 , Accuracy:(56.0)
#
# Test set: Average loss: 0.0197, Accuracy:(68.5625)
#
# *************************************************************************************************************************************
# Train Epoch: 59 [0/2500 (0%)]	Loss: 0.607722 , Accuracy:(69.0)
#
# Train Epoch: 59 [1600/2500 (63%)]	Loss: 0.576830 , Accuracy:(78.0)
#
# Train set: Average loss: 0.0197, Accuracy:(66.89873504638672)
#
# -------------------------------------------------------
# Test Epoch: 59 [0/500 (0%)]	Loss: 0.606504 , Accuracy:(69.0)
#
# Test set: Average loss: 0.0198, Accuracy:(68.6875)
#
# *************************************************************************************************************************************
# Train Epoch: 60 [0/2500 (0%)]	Loss: 0.673953 , Accuracy:(62.0)
#
# Train Epoch: 60 [1600/2500 (63%)]	Loss: 0.632508 , Accuracy:(69.0)
#
# Train set: Average loss: 0.0197, Accuracy:(66.88607788085938)
#
# -------------------------------------------------------
# Test Epoch: 60 [0/500 (0%)]	Loss: 0.634337 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0198, Accuracy:(68.1875)
#
# *************************************************************************************************************************************
# Train Epoch: 61 [0/2500 (0%)]	Loss: 0.605275 , Accuracy:(69.0)
#
# Train Epoch: 61 [1600/2500 (63%)]	Loss: 0.815728 , Accuracy:(44.0)
#
# Train set: Average loss: 0.0196, Accuracy:(67.17721557617188)
#
# -------------------------------------------------------
# Test Epoch: 61 [0/500 (0%)]	Loss: 0.669563 , Accuracy:(59.0)
#
# Test set: Average loss: 0.0197, Accuracy:(68.375)
#
# *************************************************************************************************************************************
# Train Epoch: 62 [0/2500 (0%)]	Loss: 0.632251 , Accuracy:(66.0)
#
# Train Epoch: 62 [1600/2500 (63%)]	Loss: 0.717126 , Accuracy:(56.0)
#
# Train set: Average loss: 0.0198, Accuracy:(66.3670883178711)
#
# -------------------------------------------------------
# Test Epoch: 62 [0/500 (0%)]	Loss: 0.749746 , Accuracy:(50.0)
#
# Test set: Average loss: 0.0197, Accuracy:(68.4375)
#
# *************************************************************************************************************************************
# Train Epoch:
or(69.), tensor(68.8750), tensor(68.5625), tensor(68.6875), tensor(68.1875), tensor(68.3750), tensor(68.4375), tensor(68.5625), tensor(69.1250), tensor(68.2500), tensor(68.6875), tensor(68.4375), tensor(68.6875), tensor(68.3125), tensor(68.2500), tensor(68.3750), tensor(68.7500), tensor(68.5000), tensor(68.8125), tensor(68.6875), tensor(68.8125), tensor(68.1875), tensor(68.8125), tensor(68.3125), tensor(68.1250), tensor(68.5000), tensor(68.1875), tensor(68.7500), tensor(68.6875), tensor(68.3750), tensor(68.8750), tensor(68.3750), tensor(68.8125), tensor(68.2500), tensor(68.8125), tensor(69.), tensor(68.6250), tensor(68.4375), tensor(68.7500), tensor(68.5000), tensor(68.6875), tensor(68.4375), tensor(68.5625), tensor(68.8125)]

# %% [markdown]
# # Plotting Your Results [4 pts]
#
# You need to provide two distinct plots, one demonstrating training and validation losses in y axis and iteration in the x axis and the other demonstrating training and validation accuracies in the y axis and iteration  in the x axis. <br><br>
# Please note that we need these plots to see if your model behaves as expected. Therefore, you may lose additional points if you do not provide these plots.

# %%
import matplotlib.pyplot as plt

# %%
# write your code in this cell 
y1 = train_losses
y2 = validation_losses
plt.figure(figsize=(10,5))
plt.plot(y1,label='training')
plt.plot(y2,label='validation')
plt.title('Epoch vs Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# write your code in this cell 
y1 = train_accs
y2 = validation_accs
plt.figure(figsize=(10,5))
plt.plot(y1,label='training')
plt.plot(y2,label='validation')
plt.title('Epoch vs Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #### Testing [5 pts]
#
# Test your final, i.e. best, model on your test set. Calculate confusion matrix, F1 score, precision and recall values and report these findings.

# %%
print(testing)
test_loader =  DataLoader(dataset=testing, batch_size=1, shuffle=False)
print(test_loader)
# Out:
# <__main__.OcularDataset object at 0x7fee65ff89b0>
# <torch.utils.data.dataloader.DataLoader object at 0x7fee65fb2080>

# %%
# write your code in this cell to test your best model with the test dataset
best_model = root + "/model.pth"
model = torch.load(best_model)
print(model)

criterion = nn.BCEWithLogitsLoss()

test_loss = 0
all_test_acc = [] 
model.eval()
with torch.no_grad():
    for batch_idx, (data, labels) in enumerate(test_loader):
        # TODO:
        # Implement test code
        data, labels = Variable(data), Variable(labels)
        output = model(data.float())

        # sum up batch loss
        loss = criterion(output, labels.float())
        test_loss +=  loss.item()
        
        test_acc = binary_acc(output, labels)
        all_test_acc.append(test_acc)


        if batch_idx % 50 == 0:
            print('Test Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} , Accuracy:({})\n'.format(
                epoch, batch_idx * len(data), len(test_loader.dataset), 100. * batch_idx / len(test_loader), loss.item(), test_acc))

avg_loss = test_loss / len(test_loader.dataset)
avg_acc = sum(all_test_acc) / len(all_test_acc) 

print('Test set: Average loss: {:.4f}, Accuracy:({})\n'.format(avg_loss, avg_acc))
print("*************************************************************************************************************************************")
# Out:
# FNet(
#   (hidden_layer1): Linear(in_features=32768, out_features=1024, bias=True)
#   (hidden_layer2): Linear(in_features=1024, out_features=256, bias=True)
#   (output_layer): Linear(in_features=256, out_features=1, bias=True)
# )
# Test Epoch: 99 [0/500 (0%)]	Loss: 0.346687 , Accuracy:(100.0)
#
# Test Epoch: 99 [50/500 (10%)]	Loss: 1.160619 , Accuracy:(0.0)
#
# Test Epoch: 99 [100/500 (20%)]	Loss: 0.257846 , Accuracy:(100.0)
#
# Test Epoch: 99 [150/500 (30%)]	Loss: 1.018772 , Accuracy:(0.0)
#
# Test Epoch: 99 [200/500 (40%)]	Loss: 0.387027 , Accuracy:(100.0)
#
# Test Epoch: 99 [250/500 (50%)]	Loss: 0.487625 , Accuracy:(100.0)
#
# Test Epoch: 99 [300/500 (60%)]	Loss: 0.397799 , Accuracy:(100.0)
#
# Test Epoch: 99 [350/500 (70%)]	Loss: 0.386744 , Accuracy:(100.0)
#
# Test Epoch: 99 [400/500 (80%)]	Loss: 0.314284 , Accuracy:(100.0)
#
# Test Epoch: 99 [450/500 (90%)]	Loss: 0.398070 , Accuracy:(100.0)
#
# Test set: Average loss: 0.6078, Accuracy:(69.19999694824219)
#
# *************************************************************************************************************************************

# %% [markdown]
# ### 2.2. Convolutional Neural Network (CNN) [30 pts]

# %% [markdown]
# #### Data Loader [5 pts]
#
# In this part, you will train a CNN for the same problem. Again, the pixel values need to be normalized to [0,1] range. Please do **not** change images to grayscale this time. First, implement the data loader (OcularDataset). You have to divide the files into three sets which are <b>train (5/7)</b>, <b>validation (1/7)</b> and **test (1/7)**.  These non-overlapping splits, which are subsets of OcularDataset, should be retrieved using the "get_dataset" function.<br> You may use your data loader from the previous sections with propoer modifications. Note that this time you do **not** need to flatten the image.

# %%
import os
import cv2
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from torch.utils.data import Dataset
import torch
from PIL import Image

# %%
class OcularDataset(Dataset):
    # TODO:
    # Define constructor for SVHNDataset class
    # HINT: You can pass processed data samples and their ground truth values as parameters 
    def __init__(self, data, label, **kwargs): # you are free to change parameters
        self.data = data
        self.label = label
        
        
    # '''This function should return sample count in the dataset'''
    def __len__(self):
        return self.data.shape[0]
    
    

    # '''This function should return a single sample and its ground truth value from the dataset corresponding to index parameter '''
    def __getitem__(self, index):
        _x = self.data[index]
        _y = self.label[index]
        return _x, _y

def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))
        
def get_dataset(root):
    # TODO: 
    # Read dataset files
    # Construct training, validation and test sets
    # Normalize datasets
    file = os.path.join(root, 'labels.xlsx')
    xl = pd.ExcelFile(file)
    labels = xl.parse('Sheet1')
    img_dir =  os.path.join(root, 'images')
    
   # I find the length of image data
    all_images = os.listdir(img_dir)
    print(all_images)
    np.random.shuffle(all_images)
    print(all_images)
    total = len (all_images)
    
    # find the length of train, val, test data sets
    train_len = int(total * 5 / 7)
    val_len = int(total * 1 / 7)
    test_len = int(total * 1 / 7)
    
    
    # according to these numbers I have divided the datas into train, val and test data sets.
    # taking train data
    train_data = []
    train_gt = []
    for i in range (0,train_len):
        img_name = all_images[i]
        img_address = os.path.join(img_dir,img_name)
        
        # opening image
        vec = Image.open(img_address)
        img = np.array(vec)
        
        # in order to normalize
        img_1d = img.reshape(-1)

        img_1d = NormalizeData(img_1d)

        normalized_img = img_1d.reshape(3,128,256)
        # print(normalized_img.shape)
        
        train_data.append(normalized_img)

        img_id = os.path.splitext(img_name)[0]
        for j in range (0,3500):
          if  labels[0][j] == int(img_id):
            train_gt.append( np.array(labels[1][j]))
            break
        if (i%500 == 0):
          print("Loaded: {}".format(i))

    
    # taking val data
    val_data = []
    val_gt = []
    start = train_len
    end = train_len + val_len
    for i in range (train_len,train_len+val_len):
        img_name = all_images[i]
        img_address = os.path.join(img_dir,img_name)
        
        # opening image 
        vec = Image.open(img_address)
        img = np.array(vec)
        
        # in order to normalize
        img_1d = img.reshape(-1)
        img_1d = NormalizeData(img_1d)
        normalized_img = img_1d.reshape(3,128,256)
        # print(normalized_img.shape)
        
        val_data.append(normalized_img)

        img_id = os.path.splitext(img_name)[0]
        for j in range (0,3500):
          if  labels[0][j] == int(img_id):
            val_gt.append( np.array(labels[1][j]))
            break
        if (i%100 == 0):
          print("Loaded: {}".format(i))

    # taking test data
    test_data = []
    test_gt = []
    start = train_len + val_len
    for i in range (start,total):
        img_name = all_images[i]
        img_address = os.path.join(img_dir,img_name)
        
        # opening image in greyscale
        vec = Image.open(img_address)
        img = np.array(vec).flatten()
        
        # in order to normalize
        img_1d = img.reshape(-1)
        img_1d = NormalizeData(img_1d)
        normalized_img = img_1d.reshape(3,128,256)
        # print(normalized_img.shape)
        
        test_data.append(normalized_img)


        img_id = os.path.splitext(img_name)[0]
        for j in range (0,3500):
          if  labels[0][j] == int(img_id):
            test_gt.append( np.array(labels[1][j]))
            break
        if (i%100 == 0):
          print("Loaded: {}".format(i))
    
    # Training data should be in type float
    train_data = np.asarray(train_data,dtype="float")
    val_data = np.asarray(val_data,dtype="float")
    test_data = np.asarray(test_data,dtype="float")

    # Converting to np array
    train_gt = np.asarray(train_gt).reshape(-1,1)
    val_gt = np.asarray(val_gt).reshape(-1,1)
    test_gt = np.asarray(test_gt).reshape(-1,1)
    
    train_dataset = OcularDataset (data = train_data, label= train_gt )
    val_dataset = OcularDataset (data = val_data, label = val_gt )
    test_dataset = OcularDataset (data = test_data, label=test_gt )
    
    return train_dataset, val_dataset, test_dataset

# %% [markdown]
# #### Convolutional Neural Network [8 pts]
#
# Now implement your CNN. ConvNet class will represent your convolutional neural network. Implement 3 layers of convolution:
# 1. <i>> 8 filters with size of 3 x 3 x 3 with stride 1 and no padding,</i><br>
#     <i>> ReLU </i><br>
# 2. <i>> 16 filters with size of 3 x 3 x 3 with stride 1 and no padding,</i><br>
#     <i>> ReLU </i><br>
#     <i>> MaxPool 2 x 2 </i><br>
# 3. <i>> 32 filters with size of 3 x 3 x 3 with stride 1 and no padding,</i><br>
#     <i>> ReLU </i><br>
#     <i>> MaxPool 2 x 2 </i><br>
#
# As a classification layer, you need to add only one more fully-connected layer at the end of the network. You need to choose the appropriate input and output neuron sizes and the activation function.

# %%
# Importing necessary modules
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

# %%
class ConvNet(nn.Module):
    '''Define your neural network'''
    def __init__(self, **kwargs): # you can add any additional parameters you want 
    # TODO:
    # You should create your neural network here
        super().__init__()
        self.cnn1 = nn.Conv2d(3, 8, kernel_size=3)
        self.cnn2 = nn.Conv2d(8, 16, kernel_size=3)
        self.cnn3 = nn.Conv2d(16, 32, kernel_size=3)
        self.fully_connected_layer = nn.Linear(59520,1)
        self.max_pool = nn.MaxPool2d(2)
     
    def forward(self, X): # you can add any additional parameters you want
    # TODO:
    # Forward propagation implementation should be here
        in_size = X.size(0)
        X = F.relu(self.cnn1(X))
        X = F.relu(self.max_pool(self.cnn2(X)))
        X = F.relu(self.max_pool(self.cnn3(X)))
        X = X.reshape(X.size(0), -1)
        X = self.fully_connected_layer(X)
        return X

# %% [markdown]
# #### Training and Testing [17 pts]
#
# Now, train your network. You need to select the appropriate loss function and your hyper-parameters.<br>
# Make sure to shuffle the samples in the training split.<br>
#  Plot the training and validation loss for each iteration. Also plot the training  and validation accuracy as another figure.<br>
#   Your model is going to run upto the "max_epoch" parameter. Pick the best model as your final model and save this model as a ".pth" file. Note that the best accuracy does not always imply the best model. Try to track losses instead of accuracies. <br>
#   Report the test performance change (In terms of accuracy, F1 score, precision and recall) between MLP and CNN and explain the reason for this change explicitly, if there is any.

# %%
def binary_acc(y_pred, y_test):
    y_pred_tag = torch.round(torch.sigmoid(y_pred))

    correct_results_sum = (y_pred_tag == y_test).sum().float()
    acc = correct_results_sum/y_test.shape[0]
    acc = torch.round(acc * 100)
    
    return acc

# ''' Train your network for a one epoch '''
def train(epoch, model, criterion, optimizer, loader): # you are free to change parameters
    model.train()

    correct = 0
    train_acc= 0
    train_loss = 0
    tot_loss = 0
    count = 0
    all_train_acc = []
    for batch_idx, (data, labels) in enumerate(loader):
        # TODO:
        # Implement training code for a one iteration
        
        # Using autograd Variable
        data, labels = Variable(data), Variable(labels)
        
        # zero out the gradient in order to do the parameter update correctly.
        optimizer.zero_grad()
        
        # giving data to model
        output = model(data.float())

        # calculating the loss and adding it to an array
        loss = criterion (output, labels.float())
        tot_loss += loss.item()

        loss.backward()
        optimizer.step()

        # calculating accuracy for each step and adding to an array
        # get the index of the max log-probability
        train_acc = binary_acc(output, labels)
        all_train_acc.append(train_acc)

        if batch_idx % 50 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} , Accuracy:({})\n'.format(
                epoch, batch_idx * len(data), len(loader.dataset), 100. * batch_idx / len(loader), loss.item(), train_acc))
    
    
    avg_loss = (tot_loss / len(loader.dataset)) 
    avg_acc = sum(all_train_acc) / len(all_train_acc) 
    print('Train set: Average loss: {:.4f}, Accuracy:({})\n'.format(avg_loss, avg_acc))
    
    print("-------------------------------------------------------")


    return avg_acc, avg_loss


# ''' Test&Validate your network '''
# you are free to change parameters
def test(model, loader, criterion):
    model.eval()
    test_loss = 0
    correct = 0
    all_test_acc = []
    with torch.no_grad():
        for batch_idx, (data, labels) in enumerate(loader):
            # TODO:
            # Implement test code
            
            # Using autograd Variable
            data, labels = Variable(data), Variable(labels)

            # giving data to model
            output = model(data.float())
            
            # sum up batch loss
            loss = criterion(output, labels.float())
            test_loss +=  loss.item()

            # get the index of the max log-probability
            test_acc = binary_acc(output, labels)
            all_test_acc.append(test_acc)

            if batch_idx % 50 == 0:
              print('Test Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} , Accuracy:({})\n'.format(
                  epoch, batch_idx * len(data), len(loader.dataset), 100. * batch_idx / len(loader), loss.item(), test_acc))

    avg_loss = test_loss / len(loader.dataset)
    avg_acc = sum(all_test_acc) / len(all_test_acc) 

    print('Test set: Average loss: {:.4f}, Accuracy:({})\n'.format(avg_loss, avg_acc))
    
    print("*************************************************************************************************************************************")
        
    return avg_acc, avg_loss

# %%
# HINT: note that your training time should not take many days.

# TODO:
# Pick your hyper parameters
max_epoch = 25
train_batch = 32
test_batch = 16
learning_rate = 0.05

use_gpu = torch.cuda.is_available()

def main(): # you are free to change parameters

    # Create train dataset loader
    # Create validation dataset loader
    # Create test dataset loader
    # initialize your GENet neural network
    # define your loss function
    
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-04) # you can play with momentum and weight_decay parameters as well
    
    # start training
    # for each epoch calculate validation performance
    # save best model according to validation performance
    
    #for epoch in range(max_epoch):
    #    train(epoch, model, criterion, optimizer, trainloader)
    #    acc = test(model, val_loader)
    #    if acc > best_acc:
    #       torch.save(model, best_path)
    ## My Main Function STARTS HERE
    print("MY MAIN FUNTION STARTS BELOW")
###### For not calculating the same thing again and again I have taken out the main from the function

# %%
print("Current Directory")
print(root)
# os.listdir(root)

print("Data is loading..")
training, val, testing = get_dataset(root)

trainloader = DataLoader(dataset=training, batch_size=train_batch, shuffle=True)
val_loader =  DataLoader(dataset=val, batch_size=train_batch, shuffle=True)
test_loader =  DataLoader(dataset=testing, batch_size=test_batch, shuffle=False)
# Out:
# Current Directory
# /content/gdrive/My Drive/Colab Notebooks/Homework3
# Data is loading..
# ['4275.jpg', '4274.jpg', '4278.jpg', '4276.jpg', '4280.jpg', '4279.jpg', '427.jpg', '4284.jpg', '4283.jpg', '4282.jpg', '4285.jpg', '4281.jpg', '4289.jpg', '4286.jpg', '4288.jpg', '4287.jpg', '4292.jpg', '428.jpg', '4293.jpg', '4290.jpg', '4291.jpg', '4295.jpg', '4296.jpg', '4297.jpg', '4294.jpg', '4299.jpg', '4300.jpg', '42.jpg', '4298.jpg', '429.jpg', '4304.jpg', '4303.jpg', '4301.jpg', '4302.jpg', '4306.jpg', '4305.jpg', '4308.jpg', '4307.jpg', '4311.jpg', '4310.jpg', '430.jpg', '4309.jpg', '4314.jpg', '4312.jpg', '4313.jpg', '4315.jpg', '4316.jpg', '4318.jpg', '431.jpg', '4317.jpg', '4319.jpg', '4324.jpg', '4322.jpg', '4323.jpg', '4320.jpg', '4321.jpg', '4325.jpg', '4327.jpg', '4326.jpg', '4330.jpg', '4329.jpg', '432.jpg', '4328.jpg', '4331.jpg', '4333.jpg', '4332.jpg', '4336.jpg', '4337.jpg', '4334.jpg', '4335.jpg', '4338.jpg', '4339.jpg', '433.jpg', '4343.jpg', '4342.jpg', '4341.jpg', '4340.jpg', '4344.jpg', '4349.jpg', '4345.jpg', '4348.jpg', '4347.jpg', '434.jpg', '4353.jpg', '4351.jpg', '4354.jpg', '4352.jpg', '4350.jpg', '4356.jpg', '4357.jpg', '4358.jpg', '4355.jpg', '4360.jpg', '435.jpg', '4359.jpg', '4365.jpg', '4361.jpg', '4362.jpg', '4364.jpg', '4368.jpg', '4366.jpg', '4367.jpg', '4369.jpg', '4371.jpg', '436.jpg', '4373.jpg', '4372.jpg', '4379.jpg', '4377.jpg', '4375.jpg', '4374.jpg', '4381.jpg', '437.jpg', '4380.jpg', '4384.j
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.5, weight_decay=2e-04)
# Out:
# Neural Network Initiliazing..
# ConvNet(
#   (cnn1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#   (cnn2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (cnn3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (fully_connected_layer): Linear(in_features=59520, out_features=1, bias=True)
#   (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
# start training
# for each epoch calculate validation performance
# save best model according to validation performance
criterion = nn.BCEWithLogitsLoss()
print("Training Start..")
# just to be sure best acc = 0 every time
best_acc = 0

validation_losses = []
validation_accs = []
train_losses = []
train_accs = []

for epoch in range(max_epoch):
    
    train_acc_epoch, train_loss_epoch = train(epoch, model, criterion,  optimizer, trainloader)
    # getting arrays of training data
    train_losses.append(train_loss_epoch)
    train_accs.append(train_acc_epoch)
    
    # these acc and loss are calculated from our validation dataset
    val_acc_epoch, val_loss_epoch = test(model, val_loader, criterion)
    # getting the array of val data
    validation_losses.append(val_loss_epoch)
    validation_accs.append(val_acc_epoch)
    
    if val_acc_epoch > best_acc:
        # need to change best acc every time new accuracy is better than before 
        best_acc = val_acc_epoch
        torch.save(model, root + "/CNN_model.pth")
# Out:
# Training Start..
# Train Epoch: 0 [0/2500 (0%)]	Loss: 0.691312 , Accuracy:(62.0)
#
# Train Epoch: 0 [1600/2500 (63%)]	Loss: 0.609850 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0200, Accuracy:(68.56961822509766)
#
# -------------------------------------------------------
# Test Epoch: 0 [0/500 (0%)]	Loss: 0.659646 , Accuracy:(62.0)
#
# Test set: Average loss: 0.0209, Accuracy:(63.1875)
#
# *************************************************************************************************************************************
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type ConvNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Train Epoch: 1 [0/2500 (0%)]	Loss: 0.624574 , Accuracy:(72.0)
#
# Train Epoch: 1 [1600/2500 (63%)]	Loss: 0.627444 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0200, Accuracy:(67.93670654296875)
#
# -------------------------------------------------------
# Test Epoch: 1 [0/500 (0%)]	Loss: 0.682056 , Accuracy:(56.0)
#
# Test set: Average loss: 0.0212, Accuracy:(62.9375)
#
# *************************************************************************************************************************************
# Train Epoch: 2 [0/2500 (0%)]	Loss: 0.664921 , Accuracy:(62.0)
#
# Train Epoch: 2 [1600/2500 (63%)]	Loss: 0.615749 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0197, Accuracy:(68.31645202636719)
#
# -------------------------------------------------------
# Test Epoch: 2 [0/500 (0%)]	Loss: 0.656376 , Accuracy:(62.0)
#
# Test set: Average loss: 0.0211, Accuracy:(62.625)
#
# *************************************************************************************************************************************
# Train Epoch: 3 [0/2500 (0%)]	Loss: 0.613379 , Accuracy:(69.0)
#
# Train Epoch: 3 [1600/2500 (63%)]	Loss: 0.695602 , Accuracy:(62.0)
#
# Train set: Average loss: 0.0196, Accuracy:(68.46835327148438)
#
# -------------------------------------------------------
# Test Epoch: 3 [0/500 (0%)]	Loss: 0.575633 , Accuracy:(75.0)
#
# Test set: Average loss: 0.0208, Accuracy:(63.25)
#
# *************************************************************************************************************************************
# Train Epoch: 4 [0/2500 (0%)]	Loss: 0.636178 , Accuracy:(66.0)
#
# Train Epoch: 4 [1600/2500 (63%)]	Loss: 0.584853 , Accuracy:(69.0)
#
# Train set: Average loss: 0.0195, Accuracy:(68.77214813232422)
#
# -------------------------------------------------------
# Test Epoch: 4 [0/500 (0%)]	Loss: 0.588097 , Accuracy:(69.0)
#
# Test set: Average loss: 0.0213, Accuracy:(63.375)
#
# *************************************************************************************************************************************
# Train Epoch: 5 [0/2500 (0%)]	Loss: 0.670626 , Accuracy:(66.0)
#
# Train Epoch: 5 [1600/2500 (63%)]	Loss: 0.622684 , Accuracy:(66.0)
#
# Train set: Average loss: 0.0195, Accuracy:(68.37974548339844)
#
# -------------------------------------------------------
# Test Epoch: 5 [0/500 (0%)]	Loss: 0.601887 , Accuracy:(69.0)
#
# Test set: Average loss: 0.0208, Accuracy:(63.0625)
#
# *************************************************************************************************************************************
# Train Epoch: 6 [0/2500 (0%)]	Loss: 0.679122 , Accuracy:(59.0)
#
# Train Epoch: 6 [1600/2500 (63%)]	Loss: 0.629177 , Accuracy:(66.0)
#
# Train set: Average loss: 0.0195, Accuracy:(68.50633239746094)
#
# -------------------------------------------------------
# Test Epoch: 6 [0/500 (0%)]	Loss: 0.648957 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0205, Accuracy:(63.125)
#
# *************************************************************************************************************************************
# Train Epoch: 7 [0/2500 (0%)]	Loss: 0.612863 , Accuracy:(69.0)
#
# Train Epoch: 7 [1600/2500 (63%)]	Loss: 0.517074 , Accuracy:(84.0)
#
# Train set: Average loss: 0.0194, Accuracy:(68.417724609375)
#
# -------------------------------------------------------
# Test Epoch: 7 [0/500 (0%)]	Loss: 0.655983 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0206, Accuracy:(63.375)
#
# *************************************************************************************************************************************
# Train Epoch: 8 [0/2500 (0%)]	Loss: 0.588977 , Accuracy:(75.0)
#
# Train Epoch: 8 [1600/2500 (63%)]	Loss: 0.548709 , Accuracy:(75.0)
#
# Train set: Average loss: 0.0193, Accuracy:(68.51898956298828)
#
# -------------------------------------------------------
# Test Epoch: 8 [0/500 (0%)]	Loss: 0.727342 , Accuracy:(53.0)
#
# Test set: Average loss: 0.0206, Accuracy:(63.5)
#
# *************************************************************************************************************************************
# Train Epoch: 9 [0/2500 (0%)]	Loss: 0.557663 , Accuracy:(75.0)
#
# Train Epoch: 9 [1600/2500 (63%)]	Loss: 0.601013 , Accuracy:(66.0)
#
# Train set: Average loss: 0.0193, Accuracy:(68.56961822509766)
#
# -------------------------------------------------------
# Test Epoch: 9 [0/500 (0%)]	Loss: 0.858636 , Accuracy:(41.0)
#
# Test set: Average loss: 0.0208, Accuracy:(63.3125)
#
# *************************************************************************************************************************************
# Train Epoch: 10 [0/2500 (0%)]	Loss: 0.592701 , Accuracy:(75.0)
#
# Train Epoch: 10 [1600/2500 (63%)]	Loss: 0.539655 , Accuracy:(75.0)
#
# Train set: Average loss: 0.0191, Accuracy:(68.81012725830078)
#
# -------------------------------------------------------
# Test Epoch: 10 [0/500 (0%)]	Loss: 0.782995 , Accuracy:(50.0)
#
# Test set: Average loss: 0.0213, Accuracy:(62.875)
#
# *************************************************************************************************************************************
# Train Epoch: 11 [0/2500 (0%)]	Loss: 0.610750 , Accuracy:(69.0)
#
# Train Epoch: 11 [1600/2500 (63%)]	Loss: 0.666169 , Accuracy:(59.0)
#
# Train set: Average loss: 0.0191, Accuracy:(68.9240493774414)
#
# -------------------------------------------------------
# Test Epoch: 11 [0/500 (0%)]	Loss: 0.836739 , Accuracy:(47.0)
#
# Test set: Average loss: 0.0215, Accuracy:(62.5625)
#
# *************************************************************************************************************************************
# Train Epoch: 12 [0/2500 (0%)]	Loss: 0.639055 , Accuracy:(62.0)
#
# Train Epoch: 12 [1600/2500 (63%)]	Loss: 0.609138 , Accuracy:(75.0)
#
# Train set: Average loss: 0.0190, Accuracy:(68.74683380126953)
#
# -------------------------------------------------------
# Test Epoch: 12 [0/500 (0%)]	Loss: 0.769023 , Accuracy:(41.0)
#
# Test set: Average loss: 0.0204, Accuracy:(62.75)
#
# *************************************************************************************************************************************
# Train Epoch: 13 [0/2500 (0%)]	Loss: 0.546885 , Accuracy:(75.0)
#
# Train Epoch: 13 [1600/2500 (63%)]	Loss: 0.582118 , Accuracy:(69.0)
#
# Train set: Average loss: 0.0189, Accuracy:(68.6582260131836)
#
# -------------------------------------------------------
# Test Epoch: 13 [0/500 (0%)]	Loss: 0.625770 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0203, Accuracy:(65.0)
#
# *************************************************************************************************************************************
# Train Epoch: 14 [0/2500 (0%)]	Loss: 0.629434 , Accuracy:(59.0)
#
# Train Epoch: 14 [1600/2500 (63%)]	Loss: 0.604572 , Accuracy:(69.0)
#
# Train set: Average loss: 0.0190, Accuracy:(68.44303894042969)
#
# -------------------------------------------------------
# Test Epoch: 14 [0/500 (0%)]	Loss: 0.657463 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0210, Accuracy:(59.0)
#
# *************************************************************************************************************************************
# Train Epoch: 15 [0/2500 (0%)]	Loss: 0.629771 , Accuracy:(56.0)
#
# Train Epoch: 15 [1600/2500 (63%)]	Loss: 0.627615 , Accuracy:(69.0)
#
# Train set: Average loss: 0.0188, Accuracy:(69.11392211914062)
#
# -------------------------------------------------------
# Test Epoch: 15 [0/500 (0%)]	Loss: 0.674142 , Accuracy:(62.0)
#
# Test set: Average loss: 0.0201, Accuracy:(63.5)
#
# *************************************************************************************************************************************
# Train Epoch: 16 [0/2500 (0%)]	Loss: 0.594197 , Accuracy:(66.0)
#
# Train Epoch: 16 [1600/2500 (63%)]	Loss: 0.568857 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0185, Accuracy:(69.13924407958984)
#
# -------------------------------------------------------
# Test Epoch: 16 [0/500 (0%)]	Loss: 0.624610 , Accuracy:(69.0)
#
# Test set: Average loss: 0.0209, Accuracy:(61.6875)
#
# *************************************************************************************************************************************
# Train Epoch: 17 [0/2500 (0%)]	Loss: 0.669297 , Accuracy:(62.0)
#
# Train Epoch: 17 [1600/2500 (63%)]	Loss: 0.597847 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0187, Accuracy:(69.13924407958984)
#
# -------------------------------------------------------
# Test Epoch: 17 [0/500 (0%)]	Loss: 0.697249 , Accuracy:(59.0)
#
# Test set: Average loss: 0.0208, Accuracy:(64.3125)
#
# *************************************************************************************************************************************
# Train Epoch: 18 [0/2500 (0%)]	Loss: 0.445155 , Accuracy:(81.0)
#
# Train Epoch: 18 [1600/2500 (63%)]	Loss: 0.482132 , Accuracy:(75.0)
#
# Train set: Average loss: 0.0184, Accuracy:(69.6329116821289)
#
# -------------------------------------------------------
# Test Epoch: 18 [0/500 (0%)]	Loss: 0.777756 , Accuracy:(53.0)
#
# Test set: Average loss: 0.0208, Accuracy:(62.9375)
#
# *************************************************************************************************************************************
# Train Epoch: 19 [0/2500 (0%)]	Loss: 0.642506 , Accuracy:(62.0)
#
# Train Epoch: 19 [1600/2500 (63%)]	Loss: 0.692554 , Accuracy:(59.0)
#
# Train set: Average loss: 0.0185, Accuracy:(69.6329116821289)
#
# -------------------------------------------------------
# Test Epoch: 19 [0/500 (0%)]	Loss: 0.674443 , Accuracy:(59.0)
#
# Test set: Average loss: 0.0207, Accuracy:(64.75)
#
# *************************************************************************************************************************************
# Train Epoch: 20 [0/2500 (0%)]	Loss: 0.598941 , Accuracy:(72.0)
#
# Train Epoch: 20 [1600/2500 (63%)]	Loss: 0.567925 , Accuracy:(69.0)
#
# Train set: Average loss: 0.0183, Accuracy:(70.25316619873047)
#
# -------------------------------------------------------
# Test Epoch: 20 [0/500 (0%)]	Loss: 0.726839 , Accuracy:(59.0)
#
# Test set: Average loss: 0.0211, Accuracy:(62.625)
#
# *************************************************************************************************************************************
# Train Epoch: 21 [0/2500 (0%)]	Loss: 0.576173 , Accuracy:(66.0)
#
# Train Epoch: 21 [1600/2500 (63%)]	Loss: 0.517646 , Accuracy:(78.0)
#
# Train set: Average loss: 0.0180, Accuracy:(70.48101043701172)
#
# -------------------------------------------------------
# Test Epoch: 21 [0/500 (0%)]	Loss: 0.697038 , Accuracy:(62.0)
#
# Test set: Average loss: 0.0220, Accuracy:(64.125)
#
# *************************************************************************************************************************************
# Train Epoch: 22 [0/2500 (0%)]	Loss: 0.535677 , Accuracy:(72.0)
#
# Train Epoch: 22 [1600/2500 (63%)]	Loss: 0.549228 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0182, Accuracy:(70.31645202636719)
#
# -------------------------------------------------------
# Test Epoch: 22 [0/500 (0%)]	Loss: 0.643735 , Accuracy:(62.0)
#
# Test set: Average loss: 0.0209, Accuracy:(64.125)
#
# *************************************************************************************************************************************
# Train Epoch: 23 [0/2500 (0%)]	Loss: 0.653895 , Accuracy:(56.0)
#
# Train Epoch: 23 [1600/2500 (63%)]	Loss: 0.502203 , Accuracy:(72.0)
#
# Train set: Average loss: 0.0179, Accuracy:(70.16455841064453)
#
# -------------------------------------------------------
# Test Epoch: 23 [0/500 (0%)]	Loss: 0.605445 , Accuracy:(66.0)
#
# Test set: Average loss: 0.0208, Accuracy:(63.0)
#
# *************************************************************************************************************************************
# Train Epoch: 24 [0/2500 (0%)]	Loss: 0.549435 , Accuracy:(72.0)
#
# Train Epoch: 24 [1600/2500 (63%)]	Loss: 0.676368 , Accuracy:(53.0)
#
# Train set: Average loss: 0.0179, Accuracy:(70.35443115234375)
#
# -------------------------------------------------------
# Test Epoch: 24 [0/500 (0%)]	Loss: 0.719498 , Accuracy:(59.0)
#
# Test set: Average loss: 0.0215, Accuracy:(63.5)
#
# *************************************************************************************************************************************

# %% [markdown]
# ### Plotting for CNN Model

# %%
import matplotlib.pyplot as plt
# write your code in this cell 
y1 = train_losses
y2 = validation_losses
plt.figure(1)
plt.figure(figsize=(10,5))
plt.plot(y1,label='training')
plt.plot(y2,label='validation')
plt.title('Epoch vs Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# write your code in this cell 
y1 = train_accs
y2 = validation_accs
plt.figure(2)
plt.figure(figsize=(10,5))
plt.plot(y1,label='training')
plt.plot(y2,label='validation')
plt.title('Epoch vs Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing CNN MODEL

# %% [markdown]
# ### 2.3 Interpretation [10 pts.]
#
# Explicitly discuss the results that you have obtained in Question 2. <ul>
#     > Among MLP and CNN , which one do you think is better? <br>
#     > What are the weaknesses and strengths of each method?<br>
#     > Why do we use max pooling layers for CNN? What would happen if we used average pooling instead? <br>
#     > How can we interpret the weights of convolutional layers? <br>
# </ul>

# %% [markdown]
# ##References
#
# Ocular Disease Recognition - ODIR5k Dataset (https://www.kaggle.com/andrewmvd/ocular-disease-recognition-odir5k)
